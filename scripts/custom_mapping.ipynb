# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
  #read in mapping file
  #add in url of file
  tc2p_df = pd.read_csv('/content/drive/MyDrive/pfam2TC.csv',
                 engine = 'python',
                 skiprows = [0],
                 usecols= [0,1],
                 names = ['pfam_ID', 'TC'])
  tc2p_df.pfam_ID.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       PF07885
# 1       PF07885
# 2       PF00520
# 3       PF02214
# 4       PF03493
#          ...
# 8862    PF02462
# 8863    PF02530
# 8864    PF02537
# 8865       TesT
# 8866       TesT
# Name: pfam_ID, Length: 8867, dtype: object>

# %%
print( tc2p_df.pfam_ID.nunique())
# Out:
# 1353

# %%
#read in tchmm name file
#obtained from downloading tcdoms hmm file
#going into tcdoms global
#getting hmmsName txt file, turn to csv and load in
tchmms_df = pd.read_csv('/content/drive/MyDrive/TChmmsName.csv',
                    engine = 'python',
                    skiprows = [0],
                    usecols = [1],
                    names = ['hmm_id']
)
tchmms_df
# Out:
#                  hmm_id
# 0      1.A.1.TD000001.0
# 1      1.A.1.TD000002.0
# 2      1.A.2.TD000001.0
# 3      1.A.2.TD000002.0
# 4      1.A.3.TD000001.0
# ..                  ...
# 357  9.B.330.TD000001.0
# 358  9.B.353.TD000001.0
# 359  9.B.358.TD000001.0
# 360  9.B.358.TD000002.0
# 361  9.B.371.TD000001.0
#
# [362 rows x 1 columns]

# %%
#formatting tchmms_df
tc_mappings = pd.DataFrame(columns = ['hmm_id', 'class_', 'subclass', 'family', 'subfamily', 'substrate'])
for tc_id in tchmms_df.hmm_id:
  str_list = tc_id.split(".")
  class_ = str_list[0]
  subclass = str_list[1]
  family = str_list[2]
  subfamily = '-'
  substrate = '-'
  tc_mappings.loc[len(tc_mappings.index)] = [tc_id, class_, subclass, family, subfamily, substrate]

# %%
tc_mappings
# Out:
#                  hmm_id class_ subclass family subfamily substrate
# 0      1.A.1.TD000001.0      1        A      1         -         -
# 1      1.A.1.TD000002.0      1        A      1         -         -
# 2      1.A.2.TD000001.0      1        A      2         -         -
# 3      1.A.2.TD000002.0      1        A      2         -         -
# 4      1.A.3.TD000001.0      1        A      3         -         -
# ..                  ...    ...      ...    ...       ...       ...
# 357  9.B.330.TD000001.0      9        B    330         -         -
# 358  9.B.353.TD000001.0      9        B    353         -         -
# 359  9.B.358.TD000001.0      9        B    358         -         -
# 360  9.B.358.TD000002.0      9        B    358         -         -
# 361  9.B.371.TD000001.0      9        B    371         -         -
#
# [362 rows x 6 columns]

# %%
#how many pfams have multiple mappings that have some form of commonality
#for each non-unique pfam figure out

# %%
#making the intermediate df will take

# %%
pfams_to_map_df = pd.DataFrame(columns = ['hmm_id', 'class_', 'subclass', 'family', 'subfamily', 'substrate'])
#note family can actually be superfamiliy at times
for P in   tc2p_df['pfam_ID'].unique():
    a = np.array([])
    b = np.array([])
    c = np.array([])
    d = np.array([])
    e = np.array([])
    for T in groupby_tc2pf.get_group(P).TC:
      tc = T.split ('.')
      #tc =  list ex: ['1', 'A', '1', '5', '11']
      a = np.append(a, tc[0])
      b = np.append(b, tc[1])
      c = np.append(c, tc[2])
      d = np.append(d, tc[3])
      e = np.append(e, tc[4])
    #if at least class is unique add to pfams to map df
    #if there is only 1 unique value
    if ((np.unique(a)).size == 1):
      pfams_to_map_df.loc[len(pfams_to_map_df.index)] = [P, int((np.unique(a)).size == 1), int((np.unique(b)).size == 1),
                                                         int((np.unique(c)).size == 1),int( (np.unique(d)).size == 1),
                                                         int((np.unique(e)).size == 1) ]

# %%
pfams_to_map_df = pfams_to_map_df.reset_index(drop=True)

# %%
pfams_to_map_df
# Out:
#        hmm_id  class_  subclass  family  subfamily  substrate
# 0     PF03493       1         1       1          1          0
# 1     PF11834       1         1       1          1          0
# 2     PF08412       1         1       1          1          0
# 3     PF08763       1         1       1          1          0
# 4     PF00060       1         1       1          0          0
# ...       ...     ...       ...     ...        ...        ...
# 1227  PF08627       1         1       1          1          1
# 1228  PF13953       1         1       1          0          0
# 1229  PF13954       1         1       1          0          0
# 1230  PF02462       1         1       1          1          0
# 1231     TesT       1         1       1          1          1
#
# [1232 rows x 6 columns]

# %%
#map this to TC_ID
#steps
#make final df
#for each id in pfams_to_map:
  #for a in [a - e]:
  #initialize 5 strs to "-"
  #if df.hmm_id[P].[a/b/c/d/e]= 0
    #BREAK
  #if df.hmm_id[P].[a/b/c/d/e]= 1
    #pull out whatever tc is mapped to that pfam
    #split the str
    #add whatever is at the index to respective str
  #add the row to the final df,
#join the TC hmms + mapping --> id = mapping)


final_mapping_df = pd.DataFrame(columns = ['hmm_id', 'class_', 'subclass', 'family', 'subfamily', 'substrate'])
groupby_tc2pf = tc2p_df.groupby('pfam_ID')
for id in pfams_to_map_df.hmm_id:
  idx = 0
  temp_str = groupby_tc2pf.get_group(id).iloc[0]['TC']
  temp_list = temp_str.split(".")
  class_ = '-'
  subclass = '-'
  family = '-'
  subfamily = '-'
  substrate = '-'
  for l in ['class_', 'subclass', 'family', 'subfamily', 'substrate']:
    comp = specific_value = pfams_to_map_df.loc[pfams_to_map_df['hmm_id'] == id, l].iloc[0]
    if comp == 1:
      if l == "class_":
        class_ = temp_list[0]
      if l == "subclass":
        subclass = temp_list[1]
      if l == "family":
        family = temp_list[2]
      if l == "subfamily":
        subfamily = temp_list[3]
      if l == "substrate":
        substrate = temp_list[4]
      idx += 1
    else:
      break
  final_mapping_df.loc[len(final_mapping_df.index)] = [id, class_ , subclass, family, subfamily, substrate]

# %%
final_mapping_df
# Out:
#        hmm_id class_ subclass family subfamily substrate
# 0     PF03493      1        A      1         3         -
# 1     PF11834      1        A      1         4         -
# 2     PF08412      1        A      1         5         -
# 3     PF08763      1        A      1        11         -
# 4     PF00060      1        A     10         -         -
# ...       ...    ...      ...    ...       ...       ...
# 1227  PF08627      2        A      7        20         2
# 1228  PF13953      1        B     11         -         -
# 1229  PF13954      1        B     11         -         -
# 1230  PF02462      1        B      6         2         -
# 1231     TesT      3        A      1         1         1
#
# [1232 rows x 6 columns]

# %%
final_mapping_df = pd.concat([final_mapping_df, tc_mappings])

# %%
final_mapping_df = final_mapping_df.reset_index(drop =True)
final_mapping_df
# Out:
#                   hmm_id class_ subclass family subfamily substrate
# 0                PF03493      1        A      1         3         -
# 1                PF11834      1        A      1         4         -
# 2                PF08412      1        A      1         5         -
# 3                PF08763      1        A      1        11         -
# 4                PF00060      1        A     10         -         -
# ...                  ...    ...      ...    ...       ...       ...
# 1589  9.B.330.TD000001.0      9        B    330         -         -
# 1590  9.B.353.TD000001.0      9        B    353         -         -
# 1591  9.B.358.TD000001.0      9        B    358         -         -
# 1592  9.B.358.TD000002.0      9        B    358         -         -
# 1593  9.B.371.TD000001.0      9        B    371         -         -
#
# [1594 rows x 6 columns]

# %%
final_mapping_df.to_csv('/content/drive/MyDrive/custom_mapping.csv', index=False)
